# %% [markdown]
# # Importing

# %%
import pandas as pd
import os

# %% [markdown]
# ## Exploring Data

# %%
'''
saving all the sensors name in a list
'''
file_list = os.listdir('cense_storage-master/Data_Set')

print('Number of Sensors is:',len(file_list),'\n')
# Out:
# Number of Sensors is: 30

# %%
'''
Constructing a dictionary of the data path
containing neccessary parameters
'''

path_dictionary = {
    
    'sensor_name' : ['urn:osh:sensor:noisemonitoring:B8-27-EB-EA-EB-EA',
                    'urn:osh:sensor:noisemonitoring:B8-27-EB-EA-12-88'],
    
     # this is fixed for now for all sensors
    'year' : str(2019),
    
    'month_option' : str(12),

    'day_option' : str(28) ,

    'hour_option' : str(0) ,
        
}


# path = 'urn:osh:sensor:noisemonitoring:B8-27-EB-EA-EB-EA' + r'/' + \
# path_dictionary['year'] + r'/' + path_dictionary['month_option'] + r'/' + \
# path_dictionary ['day_option'] + r'/' + path_dictionary['hour_option'] + '.zip'


path_2 = 'cense_storage-master/Data_Set/' + path_dictionary['sensor_name'][0] + r'/' + \
path_dictionary['year'] + r'/' + path_dictionary['month_option'] + r'/' + \
path_dictionary ['day_option'] + r'/' + path_dictionary['hour_option'] + '.zip'



sensor_df = pd.read_csv(path_2) 

print('The shape of the data is:',sensor_df.shape,'\n')

sensor_df.head()
# Out:
# The shape of the data is: (28799, 32)
#    1577487602011  66.01  70.92  41.78  39.03  64.55  53.39  54.25  55.27  \
# 0  1577487602136  67.84  72.95  45.70  43.54  66.96  56.82  61.57  61.22
# 1  1577487602261  67.36  73.46  54.47  53.10  69.58  60.03  55.47  62.48
# 2  1577487602386  68.09  73.74  49.63  46.26  67.53  60.16  55.50  64.15
# 3  1577487602511  68.07  75.73  44.98  41.91  71.88  58.45  57.91  63.23
# 4  1577487602636  68.21  76.68  53.81  50.61  72.78  60.23  59.77  67.36
#
#    61.49  ...  54.21.1  55.71  53.73  51.61  47.31  48.45  48.69  46.16  \
# 0  59.71  ...    55.48  57.98  55.29  53.26  48.07  49.38  47.96  46.49
# 1  59.70  ...    56.22  57.85  55.60  54.70  48.48  51.06  49.44  47.60
# 2  57.33  ...    56.47  58.00  56.31  55.19  49.63  51.34  49.52  48.56
# 3  64.33  ...    57.35  58.56  54.54  55.20  49.53  51.32  49.22  48.00
# 4  66.73  ...    57.30  59.98  54.90  54.69  49.41  50.04  48.97  49.51
#
#    46.32  47.29
# 0  48.57  48.81
# 1  49.16  49.56
# ...
